# %% [markdown]
# # <font color=4197EC> **Problem Statment**<br>Email is a powerful tool for communication It is one of the most popular and secure mediums for online transferring and communicating messages or data through the web.But, due to social networks, most of the emails contain unwanted information which is called spam. Identifying such spam emails is one of the important challenges. In this project, we will use the PYTHON text classification technique to identify or classify email spam messages.<br> On Email Dataset, we will also compare which algorithm is best for text classification.
# # <font color=49EBF3>Task: Email messages spam or not spam

# %% [markdown]
# # <strong> Essential Steps
# - <strong> Load Data
# - <strong> EDA
# - <strong> Data Cleaning
# - <strong> Text Prepocessing
# - <strong> Model Building
# - <strong> Evaluation
# - <strong> Fine Tune Model For Improment Result

# %% [markdown]
# # **Essential Import Library**

# %%
import numpy as np
import pandas as pd

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
cv = CountVectorizer()
tfidfv = TfidfVectorizer()

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB, GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier

import matplotlib.pyplot as plt
import seaborn as sns
import nltk

import warnings

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# ## Load the Dataset

# %%
# !file -bi /content/drive/MyDrive/EziTech/EmailSpam/Unispam.csv
# Out:
# text/csv; charset=unknown-8bit

# %%
Email_data = pd.read_csv('/content/drive/MyDrive/EziTech/EmailSpam/Unispam.csv', encoding='latin-1')

# %%
Email_data.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
print(Email_data.shape)
Email_data.info()
# Out:
# (5572, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %% [markdown]
# # Rename Column

# %%
Email_data.rename(columns={'v1':'message_type', 'v2':'messages'}, inplace=True)

# %%
Email_data.head()
# Out:
#   message_type                                           messages Unnamed: 2  \
# 0          ham  Go until jurong point, crazy.. Available only ...        NaN
# 1          ham                      Ok lar... Joking wif u oni...        NaN
# 2         spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3          ham  U dun say so early hor... U c already then say...        NaN
# 4          ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
Email_data.columns
# Out:
# Index(['message_type', 'messages', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], dtype='object')

# %% [markdown]
# ## **Drop The Column**<br>
# I dropping the column of title because this column is not part of the text preprocessing, we will use column messages for text preprocessing.

# %%
Email_data = pd.DataFrame(Email_data.drop({'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'}, axis=1))

# %%
Email_data.head()
# Out:
#   message_type                                           messages
# 0          ham  Go until jurong point, crazy.. Available only ...
# 1          ham                      Ok lar... Joking wif u oni...
# 2         spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3          ham  U dun say so early hor... U c already then say...
# 4          ham  Nah I don't think he goes to usf, he lives aro...

# %%
Email_data['message_type'].unique()
# Out:
# array(['ham', 'spam'], dtype=object)

# %%
Email_data['message_type'].isnull().sum()
# Out:
# 0

# %% [markdown]
# Our Target column is "messages type". Now we will do Label encoding of "message type" column

# %%
from sklearn.preprocessing import LabelEncoder
encod = LabelEncoder()

# %%
Email_data['message_type'] = encod.fit_transform(Email_data['message_type'])

# %% [markdown]
# # Spam message = 1, Not Spam messgae = 0

# %%
Email_data.head()
# Out:
#    message_type                                           messages
# 0             0  Go until jurong point, crazy.. Available only ...
# 1             0                      Ok lar... Joking wif u oni...
# 2             1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3             0  U dun say so early hor... U c already then say...
# 4             0  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# **According to above info spam = 1 and not spam = 0**

# %%
Email_data.duplicated().sum()
# Out:
# 403

# %%
Email_data = Email_data.drop_duplicates(keep='first')

# %%
Email_data.duplicated().sum()
# Out:
# 0

# %%
Email_data.shape
# Out:
# (5169, 2)

# %% [markdown]
# No are missing values in the dataset according to the above info. Data is Clean.

# %%
Email_data['message_type'].value_counts()

# not spam = 0
# spam = 1
# Out:
# 0    4516
# 1     653
# Name: message_type, dtype: int64

# %%
plt.pie(Email_data['message_type'].value_counts(), labels=['not spam','Spam'], autopct="%0.2f")
plt.show()

# %% [markdown]
# **Data is Imbalance**

# %% [markdown]
# # Check the number of character each meassage

# %%
Email_data['num_char'] = Email_data['messages'].apply(len)

# %%
Email_data.head()
# Out:
#    message_type                                           messages  num_char
# 0             0  Go until jurong point, crazy.. Available only ...       111
# 1             0                      Ok lar... Joking wif u oni...        29
# 2             1  Free entry in 2 a wkly comp to win FA Cup fina...       155
# 3             0  U dun say so early hor... U c already then say...        49
# 4             0  Nah I don't think he goes to usf, he lives aro...        61

# %%
Email_data['messages'].apply(lambda x:(nltk.word_tokenize(x)))
# Out:
# 0       [Go, until, jurong, point, ,, crazy, .., Avail...
# 1                [Ok, lar, ..., Joking, wif, u, oni, ...]
# 2       [Free, entry, in, 2, a, wkly, comp, to, win, F...
# 3       [U, dun, say, so, early, hor, ..., U, c, alrea...
# 4       [Nah, I, do, n't, think, he, goes, to, usf, ,,...
#                               ...
# 5567    [This, is, the, 2nd, time, we, have, tried, 2,...
# 5568     [Will, Ì_, b, going, to, esplanade, fr, home, ?]
# 5569    [Pity, ,, *, was, in, mood, for, that, ., So, ...
# 5570    [The, guy, did, some, bitching, but, I, acted,...
# 5571                  [Rofl, ., Its, true, to, its, name]
# Name: messages, Length: 5169, dtype: object

# %%
Email_data['num_word'] = Email_data['messages'].apply(lambda x:len(nltk.word_tokenize(x)))
Email_data.head()
# Out:
#    message_type                                           messages  num_char  \
# 0             0  Go until jurong point, crazy.. Available only ...       111
# 1             0                      Ok lar... Joking wif u oni...        29
# 2             1  Free entry in 2 a wkly comp to win FA Cup fina...       155
# 3             0  U dun say so early hor... U c already then say...        49
# 4             0  Nah I don't think he goes to usf, he lives aro...        61
#
#    num_word
# 0        24
# 1         8
# 2        37
# 3        13
# 4        15

# %% [markdown]
# # EDA

# %%
Email_data[['num_char','num_word']].describe()
# Out:
#           num_char     num_word
# count  5169.000000  5169.000000
# mean     78.977945    18.455794
# std      58.236293    13.324758
# min       2.000000     1.000000
# 25%      36.000000     9.000000
# 50%      60.000000    15.000000
# 75%     117.000000    26.000000
# max     910.000000   220.000000

# %%
# not spam = 0
Email_data[Email_data['message_type'] == 0][['num_char','num_word']].describe()
# Out:
#           num_char     num_word
# count  4516.000000  4516.000000
# mean     70.459256    17.123782
# std      56.358207    13.493970
# min       2.000000     1.000000
# 25%      34.000000     8.000000
# 50%      52.000000    13.000000
# 75%      90.000000    22.000000
# max     910.000000   220.000000

# %%
# Spam = 1
Email_data[Email_data['message_type'] == 1][['num_char','num_word']].describe()
# Out:
#          num_char    num_word
# count  653.000000  653.000000
# mean   137.891271   27.667688
# std     30.137753    7.008418
# min     13.000000    2.000000
# 25%    132.000000   25.000000
# 50%    149.000000   29.000000
# 75%    157.000000   32.000000
# max    224.000000   46.000000

# %%
plt.figure(figsize=(8,5))
sns.histplot(Email_data[Email_data['message_type']==0]['num_char']) # Not spam = 0
plt.title("Not Spam")
# Out:
# Text(0.5, 1.0, 'Not Spam')

# %%
plt.figure(figsize=(8,5))
sns.histplot(Email_data[Email_data['message_type']==1]['num_char']) # Spam = 1
plt.title("Spam")
# Out:
# Text(0.5, 1.0, 'Spam')

# %%
plt.figure(figsize=(8,5))
sns.histplot(Email_data[Email_data['message_type']==0]['num_char']) # Not spam = 0

sns.histplot(Email_data[Email_data['message_type']==1]['num_char']) # Spam = 1
plt.title("Difference Between Spam and Not Spam messages")
# Out:
# Text(0.5, 1.0, 'Difference Between Spam and Not Spam messages')

# %% [markdown]
# # **Now We Will Do Text Preprocessing**<br>
# and follow will these essential steps.
# - Convert the all words lower case.
# - Tokenizaton
# - Remove the special characters.
# - Remove punctuation
# - Stemming

# %%
import string
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
# We will Create a function that will perform the above task

def text_transform(text):
  text = text.lower()
  text = nltk.word_tokenize(text)

  y = []

  for i in text:
    if i.isalnum():
      y.append(i)

  text = y[:]
  y.clear()

  for i in text:
    if i not in stopwords.words('english') and i not in string.punctuation:
      y.append(i)

  text = y[:]
  y.clear()

  for i in text:
    y.append(ps.stem(i))

  return " ".join(y)

# %% [markdown]
# # Check the function result

# %%
text_transform('Hi How Are %% / Pakistan is a beautiful ciuntry? ')
# Out:
# 'hi pakistan beauti ciuntri'

# %%
Email_data['text_Transformed'] = Email_data['messages'].apply(text_transform)
Email_data.head()
# Out:
#    message_type                                           messages  num_char  \
# 0             0  Go until jurong point, crazy.. Available only ...       111
# 1             0                      Ok lar... Joking wif u oni...        29
# 2             1  Free entry in 2 a wkly comp to win FA Cup fina...       155
# 3             0  U dun say so early hor... U c already then say...        49
# 4             0  Nah I don't think he goes to usf, he lives aro...        61
#
#    num_word                                   text_Transformed
# 0        24  go jurong point crazi avail bugi n great world...
# 1         8                              ok lar joke wif u oni
# 2        37  free entri 2 wkli comp win fa cup final tkt 21...
# 3        13                u dun say earli hor u c alreadi say
# 4        15               nah think goe usf live around though

# %% [markdown]
# # **Model Building**

# %%
tfidfVecMax = TfidfVectorizer(max_features=2000)

from sklearn.model_selection import train_test_split

# %%
data1 = Email_data
data2 = Email_data
data3 = Email_data
data4 = Email_data
data5 = Email_data

# %%
data1.columns
# Out:
# Index(['message_type', 'messages', 'num_char', 'num_word', 'text_Transformed'], dtype='object')

# %% [markdown]
# # Using CountVectorizer

# %%
X = cv.fit_transform(data1['text_Transformed']).toarray()

# %%
X.shape
# Out:
# (5169, 6708)

# %%
y = Email_data['message_type'].values

# %%
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=37)

# %% [markdown]
# #  <font color='bluewight' ><strong>Training with different Model</font>

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split,KFold,cross_val_score,GridSearchCV,RandomizedSearchCV
from sklearn.metrics import accuracy_score,classification_report,f1_score, confusion_matrix, precision_score

# %%
Gnb = GaussianNB()
Mnb = MultinomialNB()
Rfc = RandomForestClassifier()
KnbC = KNeighborsClassifier()
DtC = DecisionTreeClassifier()
Xgb = XGBClassifier()

# %%
from sklearn.metrics import accuracy_score,f1_score, confusion_matrix, precision_score

# %%
#  Training with GaussianNB Model
gnb_X_train = X_train
gnb_X_test =  X_test
gnb_y_train = y_train
gnb_y_test = y_test

Gnb.fit(gnb_X_train, gnb_y_train)

Gnb_pred = Gnb.predict(gnb_X_test)

#  Training with MultinomialNB Model
Mnb_X_train = X_train
Mnb_X_test =  X_test
Mnb_y_train = y_train
Mnb_y_test = y_test

Mnb.fit(Mnb_X_train, Mnb_y_train)

Mnb_pred = Mnb.predict(Mnb_X_test)

#  Training with  RandomForest Model
Rfc_X_train = X_train
Rfc_X_test =  X_test
Rfc_y_train = y_train
Rfc_y_test = y_test

Rfc.fit(Rfc_X_train, Rfc_y_train)

Rfc_pred = Rfc.predict(Rfc_X_test)

#  Training with  KNeighbors Model
Kn_X_train = X_train
Kn_X_test =  X_test
Kn_y_train = y_train
Kn_y_test = y_test

KnbC.fit(Kn_X_train, Kn_y_train)

Kn_pred = KnbC.predict(Kn_X_test)

#  Training with  DecisionTree Model
Dt_X_train = X_train
Dt_X_test =  X_test
Dt_y_train = y_train
Dt_y_test = y_test

DtC.fit(Dt_X_train, Dt_y_train)

Dt_pred = DtC.predict(Dt_X_test)

#  Training with  XGBoost Model
Xgb_X_train = X_train
Xgb_X_test =  X_test
Xgb_y_train = y_train
Xgb_y_test = y_test

Xgb.fit(Xgb_X_train, Xgb_y_train)

Xgb_pred = Xgb.predict(Xgb_X_test)

# %% [markdown]
# # Evaluation

# %%
ps_gnb = precision_score(gnb_y_test,Gnb_pred)
as_gnb = accuracy_score(gnb_y_test,Gnb_pred)
fs_gnb = f1_score(gnb_y_test,Gnb_pred)

ps_mnb = precision_score(Mnb_y_test,Mnb_pred)
as_mnb = accuracy_score(Mnb_y_test,Mnb_pred)
fs_mnb = f1_score(Mnb_y_test,Mnb_pred)

ps_rf = precision_score(Rfc_y_test,Rfc_pred)
as_rf = accuracy_score(Rfc_y_test,Rfc_pred)
fs_rf = f1_score(Rfc_y_test,Rfc_pred)

ps_kn = precision_score(Kn_y_test,Kn_pred)
as_kn = accuracy_score(Kn_y_test,Kn_pred)
fs_kn = f1_score(Kn_y_test,Kn_pred)

ps_dt = precision_score(Dt_y_test,Dt_pred)
as_dt = accuracy_score(Dt_y_test,Dt_pred)
fs_dt = f1_score(Dt_y_test,Dt_pred)

ps_xg = precision_score(Xgb_y_test,Xgb_pred)
as_xg = accuracy_score(Xgb_y_test,Xgb_pred)
fs_xg = f1_score(Xgb_y_test,Xgb_pred)

# %%
E_data = {
    'Model': ['GNB', 'MNB', 'RF', 'KN', 'DT','XGBoost'],
    'PrecisionScore': [ps_gnb, ps_mnb, ps_rf, ps_kn, ps_dt, ps_xg],
    'AccScore': [as_gnb, as_mnb, as_rf, as_kn, as_dt, as_xg],
    'f1_Score': [fs_gnb,fs_mnb, fs_rf, fs_kn, fs_dt, fs_xg]
    }

e_df = pd.DataFrame(E_data)
print(e_df)
# Out:
#      Model  PrecisionScore  AccScore  f1_Score
# 0      GNB        0.454545  0.865571  0.589971
# 1      MNB        0.855932  0.966151  0.852321
# 2       RF        1.000000  0.963250  0.810000
# 3       KN        1.000000  0.925532  0.521739
# 4       DT        0.915789  0.961315  0.813084
# 5  XGBoost        0.948980  0.970019  0.857143

# %% [markdown]
# # ***Checked above the result use with CountVectorizer***<br>
# *******

# %% [markdown]
# # **Useing Tfidf**

# %%
X = tfidfv.fit_transform(data2['text_Transformed']).toarray()

# %%
y = Email_data['message_type'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=37)

# %%
#  Training with GaussianNB Model
gnb_X_train = X_train
gnb_X_test =  X_test
gnb_y_train = y_train
gnb_y_test = y_test

Gnb.fit(gnb_X_train, gnb_y_train)

Gnb_pred = Gnb.predict(gnb_X_test)

#  Training with MultinomialNB Model
Mnb_X_train = X_train
Mnb_X_test =  X_test
Mnb_y_train = y_train
Mnb_y_test = y_test

Mnb.fit(Mnb_X_train, Mnb_y_train)

Mnb_pred = Mnb.predict(Mnb_X_test)

#  Training with  RandomForest Model
Rfc_X_train = X_train
Rfc_X_test =  X_test
Rfc_y_train = y_train
Rfc_y_test = y_test

Rfc.fit(Rfc_X_train, Rfc_y_train)

Rfc_pred = Rfc.predict(Rfc_X_test)

#  Training with  KNeighbors Model
Kn_X_train = X_train
Kn_X_test =  X_test
Kn_y_train = y_train
Kn_y_test = y_test

KnbC.fit(Kn_X_train, Kn_y_train)

Kn_pred = KnbC.predict(Kn_X_test)

#  Training with  DecisionTree Model
Dt_X_train = X_train
Dt_X_test =  X_test
Dt_y_train = y_train
Dt_y_test = y_test

DtC.fit(Dt_X_train, Dt_y_train)

Dt_pred = DtC.predict(Dt_X_test)

#  Training with  XGBoost Model
Xgb_X_train = X_train
Xgb_X_test =  X_test
Xgb_y_train = y_train
Xgb_y_test = y_test

Xgb.fit(Xgb_X_train, Xgb_y_train)

Xgb_pred = Xgb.predict(Xgb_X_test)

# %% [markdown]
# # Model Evaluation

# %%
ps_gnb = precision_score(gnb_y_test,Gnb_pred)
as_gnb = accuracy_score(gnb_y_test,Gnb_pred)
fs_gnb = f1_score(gnb_y_test,Gnb_pred)

ps_mnb = precision_score(Mnb_y_test,Mnb_pred)
as_mnb = accuracy_score(Mnb_y_test,Mnb_pred)
fs_mnb = f1_score(Mnb_y_test,Mnb_pred)

ps_rf = precision_score(Rfc_y_test,Rfc_pred)
as_rf = accuracy_score(Rfc_y_test,Rfc_pred)
fs_rf = f1_score(Rfc_y_test,Rfc_pred)

ps_kn = precision_score(Kn_y_test,Kn_pred)
as_kn = accuracy_score(Kn_y_test,Kn_pred)
fs_kn = f1_score(Kn_y_test,Kn_pred)

ps_dt = precision_score(Dt_y_test,Dt_pred)
as_dt = accuracy_score(Dt_y_test,Dt_pred)
fs_dt = f1_score(Dt_y_test,Dt_pred)

ps_xg = precision_score(Xgb_y_test,Xgb_pred)
as_xg = accuracy_score(Xgb_y_test,Xgb_pred)
fs_xg = f1_score(Xgb_y_test,Xgb_pred)

# %%
E_data2 = {
    'Model': ['GNB', 'MNB', 'RF', 'KN', 'DT','XGBoost'],
    'PrecisionScore': [ps_gnb, ps_mnb, ps_rf, ps_kn, ps_dt, ps_xg],
    'AccScore': [as_gnb, as_mnb, as_rf, as_kn, as_dt, as_xg],
    'f1_Score': [fs_gnb,fs_mnb, fs_rf, fs_kn, fs_dt, fs_xg]
    }

e_df2 = pd.DataFrame(E_data2)
print(e_df2)
# Out:
#      Model  PrecisionScore  AccScore  f1_Score
# 0      GNB        0.449074  0.863636  0.579104
# 1      MNB        1.000000  0.963250  0.810000
# 2       RF        1.000000  0.971954  0.861244
# 3       KN        1.000000  0.911992  0.380952
# 4       DT        0.826923  0.950677  0.771300
# 5  XGBoost        0.923077  0.970019  0.860987

# %% [markdown]
# # ***Checked above the result use with TfidfVectorizer***<br>
# **************

# %% [markdown]
# ***************

# %% [markdown]
# # **Using Tfidf with max feature**

# %%
X = tfidfVecMax.fit_transform(data3['text_Transformed']).toarray()

# %%
y = Email_data['message_type'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=37)

# %%
#  Training with GaussianNB Model
gnb_X_train = X_train
gnb_X_test =  X_test
gnb_y_train = y_train
gnb_y_test = y_test

Gnb.fit(gnb_X_train, gnb_y_train)

Gnb_pred = Gnb.predict(gnb_X_test)

#  Training with MultinomialNB Model
Mnb_X_train = X_train
Mnb_X_test =  X_test
Mnb_y_train = y_train
Mnb_y_test = y_test

Mnb.fit(Mnb_X_train, Mnb_y_train)

Mnb_pred = Mnb.predict(Mnb_X_test)

#  Training with  RandomForest Model
Rfc_X_train = X_train
Rfc_X_test =  X_test
Rfc_y_train = y_train
Rfc_y_test = y_test

Rfc.fit(Rfc_X_train, Rfc_y_train)

Rfc_pred = Rfc.predict(Rfc_X_test)

#  Training with  KNeighbors Model
Kn_X_train = X_train
Kn_X_test =  X_test
Kn_y_train = y_train
Kn_y_test = y_test

KnbC.fit(Kn_X_train, Kn_y_train)

Kn_pred = KnbC.predict(Kn_X_test)

#  Training with  DecisionTree Model
Dt_X_train = X_train
Dt_X_test =  X_test
Dt_y_train = y_train
Dt_y_test = y_test

DtC.fit(Dt_X_train, Dt_y_train)

Dt_pred = DtC.predict(Dt_X_test)

#  Training with  XGBoost Model
Xgb_X_train = X_train
Xgb_X_test =  X_test
Xgb_y_train = y_train
Xgb_y_test = y_test

Xgb.fit(Xgb_X_train, Xgb_y_train)

Xgb_pred = Xgb.predict(Xgb_X_test)

# %% [markdown]
# # Evaluation

# %%
ps_gnb = precision_score(gnb_y_test,Gnb_pred)
as_gnb = accuracy_score(gnb_y_test,Gnb_pred)
fs_gnb = f1_score(gnb_y_test,Gnb_pred)

ps_mnb = precision_score(Mnb_y_test,Mnb_pred)
as_mnb = accuracy_score(Mnb_y_test,Mnb_pred)
fs_mnb = f1_score(Mnb_y_test,Mnb_pred)

ps_rf = precision_score(Rfc_y_test,Rfc_pred)
as_rf = accuracy_score(Rfc_y_test,Rfc_pred)
fs_rf = f1_score(Rfc_y_test,Rfc_pred)

ps_kn = precision_score(Kn_y_test,Kn_pred)
as_kn = accuracy_score(Kn_y_test,Kn_pred)
fs_kn = f1_score(Kn_y_test,Kn_pred)

ps_dt = precision_score(Dt_y_test,Dt_pred)
as_dt = accuracy_score(Dt_y_test,Dt_pred)
fs_dt = f1_score(Dt_y_test,Dt_pred)

ps_xg = precision_score(Xgb_y_test,Xgb_pred)
as_xg = accuracy_score(Xgb_y_test,Xgb_pred)
fs_xg = f1_score(Xgb_y_test,Xgb_pred)

# %%
E_data3 = {
    'Model': ['GNB', 'MNB', 'RF', 'KN', 'DT','XGBoost'],
    'PrecisionScore': [ps_gnb, ps_mnb, ps_rf, ps_kn, ps_dt, ps_xg],
    'AccScore': [as_gnb, as_mnb, as_rf, as_kn, as_dt, as_xg],
    'f1_Score': [fs_gnb,fs_mnb, fs_rf, fs_kn, fs_dt, fs_xg]
    }

e_df3 = pd.DataFrame(E_data3)
print(e_df3)
# Out:
#      Model  PrecisionScore  AccScore  f1_Score
# 0      GNB        0.396761  0.835590  0.535519
# 1      MNB        1.000000  0.973888  0.872038
# 2       RF        1.000000  0.973888  0.872038
# 3       KN        1.000000  0.926499  0.530864
# 4       DT        0.784483  0.948743  0.774468
# 5  XGBoost        0.932039  0.970986  0.864865

# %% [markdown]
# # ***Checked above the result use with TfidfVectorizer Max Feature***<br>
# *************

# %%
print("CV")
print(e_df)
print("TfidfVectorizer")
print(e_df2)
print("TfidfVectorizer Max Feature")
print(e_df3)
# Out:
# CV
#      Model  PrecisionScore  AccScore  f1_Score
# 0      GNB        0.454545  0.865571  0.589971
# 1      MNB        0.855932  0.966151  0.852321
# 2       RF        1.000000  0.963250  0.810000
# 3       KN        1.000000  0.925532  0.521739
# 4       DT        0.915789  0.961315  0.813084
# 5  XGBoost        0.948980  0.970019  0.857143
# TfidfVectorizer
#      Model  PrecisionScore  AccScore  f1_Score
# 0      GNB        0.449074  0.863636  0.579104
# 1      MNB        1.000000  0.963250  0.810000
# 2       RF        1.000000  0.971954  0.861244
# 3       KN        1.000000  0.911992  0.380952
# 4       DT        0.826923  0.950677  0.771300
# 5  XGBoost        0.923077  0.970019  0.860987
# TfidfVectorizer Max Feature
#      Model  PrecisionScore  AccScore  f1_Score
# 0      GNB        0.396761  0.835590  0.535519
# 1      MNB        1.000000  0.973888  0.872038
# 2       RF        1.000000  0.973888  0.872038
# 3       KN        1.000000  0.926499  0.530864
# ...

# %% [markdown]
# #  <font color='bluewight' >**According to my observation, I got the best results with Tfidfvectorizer Max Feature. RandomForestClassifier and MultinomialNB model showing the best result**<br>
# Model
#
# MNB =>    PrecisionScore = 1.000000  AccScore = 0.973888  f1_Score = 0.872038
#
# RF  =>   PrecisionScore = 1.000000  AccScore = 0.973888  f1_Score = 0.872038

# %% [markdown]
# # Save Model

# %%
# # Saving the trained model
import pickle

model_path = "/content/drive/MyDrive/EziTech/EmailSpam/Rfc_EsModel.pkl"

# Save the trained model using pickle
with open(model_path, 'wb') as f:
    pickle.dump(Rfc, f)
# grid_search.save_model(model_path)
print("Model saved successfully at:", model_path)
# Out:
# Model saved successfully at: /content/drive/MyDrive/EziTech/EmailSpam/Rfc_EsModel.pkl

# %%
# # Saving the trained model
import pickle

model_path = "/content/drive/MyDrive/EziTech/EmailSpam/tfidf_maxF_vec.pkl"

# Save the trained model using pickle
with open(model_path, 'wb') as f:
    pickle.dump(tfidfVecMax, f)
# grid_search.save_model(model_path)
print("Model saved successfully at:", model_path)
# Out:
# Model saved successfully at: /content/drive/MyDrive/EziTech/EmailSpam/tfidf_maxF_vec.pkl
